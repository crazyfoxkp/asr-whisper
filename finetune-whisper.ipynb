# %% [markdown]
# <a href="https://colab.research.google.com/github/crazyfoxkp/asr-whisper/blob/main/finetune-whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets>=2.6.1
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install gradio
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-mnzhcpwm
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-mnzhcpwm
#   Resolved https://github.com/huggingface/transformers to commit 1bd604d11c405dfb8b78bda4062d88fc75c17de0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 40.8 MB/s eta 0:00:00
# ...
#   Created wheel for transformers: filename=transformers-4.46.0.dev0-py3-none-any.whl size=9964557 sha256=126a317baff32be5ed86a21d746b69fc1520ff2c18231bb7ec9e568504623769
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gpeu01ma/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
# ...

# %%
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import torch

# %%
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# STEP 0. Loging to Hugging Face
# get your account token from https://huggingface.co/settings/tokens
# import the relavant libraries for loggin in
from huggingface_hub import HfApi, HfFolder, login

def login_hugging_face(token: str) -> None:
    """
    Loging to Hugging Face portal with a given token.
    """
    api = HfApi()
    api.set_access_token(token)
    folder = HfFolder()
    folder.save_token(token)

    return None
token = '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'
#login_hugging_face(token)
login(token)
print('We are logged in to Hugging Face now!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-810a34a30e52> in <cell line: 19>()
#      17 #token = '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'
#      18 #login_hugging_face(token)
# ---> 19 login(HF_TOKEN)
#      20 print('We are logged in to Hugging Face now!')
#
# NameError: name 'HF_TOKEN' is not defined
